# %%
pip install goslate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached goslate-1.5.4.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached futures-3.0.5.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for goslate: filename=goslate-1.5.4-py3-none-any.whl size=11628 sha256=4a94694955f8ffd2eb9a488bd74c2254f28f7ac8c2e262177a63891cbda812ce
#   Stored in directory: /home/mitu/.cache/pip/wheels/b5/30/e9/63b6de83667be2977ee793a146a2c80f8e588d5c0203b39dc9
# ...
#   Created wheel for futures: filename=futures-3.0.5-py3-none-any.whl size=13910 sha256=972d308dc5fdd7992ee3fa3fb2fe62507c3c85c44e7ede32a3886dc4e024c3fb
#   Stored in directory: /home/mitu/.cache/pip/wheels/ef/af/93/48739d464ba97d4cdc77c627d282f9794c8d276e42aaa92160
# ...

# %%
from goslate import Goslate

# %%
trans = Goslate()

# %%
text = 'Hello friends! How are you? I will teach you Python programming.'

# %%
trans.translate(text=text, target_language='mr')
# Out:
# 'नमस्कार मित्रांनो! कसे आहात? मी तुम्हाला पायथन प्रोग्रामिंग शिकवतो.'

# %%
trans.get_languages()
# Out:
# {'ab': 'Abkhaz',
#  'ace': 'Acehnese',
#  'ach': 'Acholi',
#  'aa': 'Afar',
#  'af': 'Afrikaans',
#  'sq': 'Albanian',
#  'alz': 'Alur',
#  'am': 'Amharic',
#  'ar': 'Arabic',
#  'hy': 'Armenian',
#  'as': 'Assamese',
#  'av': 'Avar',
#  'awa': 'Awadhi',
#  'ay': 'Aymara',
#  'az': 'Azerbaijani',
#  'ban': 'Balinese',
#  'bal': 'Baluchi',
#  'bm': 'Bambara',
#  'bci': 'Baoulé',
#  'ba': 'Bashkir',
#  'eu': 'Basque',
#  'btx': 'Batak Karo',
#  'bts': 'Batak Simalungun',
#  'bbc': 'Batak Toba',
#  'be': 'Belarusian',
#  'bem': 'Bemba',
#  'bn': 'Bengali',
#  'bew': 'Betawi',
#  'bho': 'Bhojpuri',
#  'bik': 'Bikol',
#  'bs': 'Bosnian',
#  'br': 'Breton',
#  'bg': 'Bulgarian',
#  'bua': 'Buryat',
#  'yue': 'Cantonese',
#  'ca': 'Catalan',
#  'ceb': 'Cebuano',
#  'ch': 'Chamorro',
#  'ce': 'Chechen',
#  'ny': 'Chichewa',
#  'zh-CN': 'Chinese (Simplified)',
#  'chk': 'Chuukese',
#  'cv': 'Chuvash',
#  'co': 'Corsican',
#  'crh': 'Crimean Tatar (Cyrillic)',
# ...

# %%
trans.translate(text=text, target_language='fr')
# Out:
# 'Bonjour les amis ! Comment vas-tu? Je vais vous apprendre la programmation Python.'

# %%
trans.translate(text=text, target_language='es')
# Out:
# '¡Hola amigos! ¿Cómo estás? Te enseñaré programación en Python.'

# %%
trans.translate(text=text, target_language='te')
# Out:
# 'హలో మిత్రులారా! మీరు ఎలా ఉన్నారు? నేను మీకు పైథాన్ ప్రోగ్రామింగ్ నేర్పిస్తాను.'

# %%
trans.translate(text=text, target_language='bn')
# Out:
# 'হ্যালো বন্ধুরা! কেমন আছেন? আমি আপনাকে পাইথন প্রোগ্রামিং শেখাব।'

# %%
trans.translate(text=text, target_language='gu')
# Out:
# 'હેલો મિત્રો! તમે કેમ છો? હું તમને પાયથોન પ્રોગ્રામિંગ શીખવીશ.'

# %%
text = '''The Great Smog of London, or Great Smog of 1952, was a severe air pollution event that affected London, England, in December 1952. A period of unusually cold weather, combined with an anticyclone and windless conditions, collected airborne pollutants—mostly arising from the use of coal—to form a thick layer of smog over the city. It lasted from Friday, 5 December to Tuesday, 9 December 1952, then dispersed quickly when the weather changed'''

# %%
trans.translate(text=text, target_language='mr')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 trans.translate(text=text, target_language='mr')
#
# File ~/.local/lib/python3.10/site-packages/goslate.py:415, in Goslate.translate(self, text, target_language, source_language)
#     413     if isinstance(text, unicode):
#     414         text = text.encode('utf-8')
# --> 415     return _unwrapper_single_element(self._translate_single_text(text, target_language, source_language))
#     417 JOINT = u'\u26ff'
#     418 UTF8_JOINT = (u'\n%s\n' % JOINT).encode('utf-8')
#
# File ~/.local/lib/python3.10/site-packages/goslate.py:340, in Goslate._translate_single_text(self, text, target_language, source_lauguage)
#     337 def make_task(text):
#     338     return lambda: self._basic_translate(text, target_language, source_lauguage)[0]
# ...
