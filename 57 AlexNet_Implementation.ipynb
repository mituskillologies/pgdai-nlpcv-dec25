# %%
import numpy as np
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, Input
import matplotlib.pyplot as plt

# %%
(x_train, y_train),(x_test, y_test) = cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
              'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Create AlexNet Architecture

# %%
model = Sequential()

model.add(Input(shape=(32,32,3)))
model.add(Conv2D(filters=128, kernel_size=(5,5), strides=(1,1),
                 activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1),
                 activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(3,3)))
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1),
                 activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(1,1), strides=(1,1),
                 activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(1,1), strides=(1,1),
                 activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 128)    │         9,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 2, 2, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 2, 2, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 2, 2, 256)      │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 2, 2, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 2, 2, 256)      │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 2, 2, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,824,266 (6.96 MB)
#  Trainable params: 1,821,962 (6.95 MB)
#  Non-trainable params: 2,304 (9.00 KB)

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history=model.fit(x_train, y_train, epochs=30, validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - accuracy: 0.3405 - loss: 1.8422 - val_accuracy: 0.4036 - val_loss: 1.6966
# Epoch 2/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.5479 - loss: 1.2886 - val_accuracy: 0.6012 - val_loss: 1.1224
# Epoch 3/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.6333 - loss: 1.0826 - val_accuracy: 0.6456 - val_loss: 1.0554
# Epoch 4/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.6816 - loss: 0.9569 - val_accuracy: 0.6825 - val_loss: 0.9160
# Epoch 5/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7045 - loss: 0.8824 - val_accuracy: 0.5121 - val_loss: 1.4969
# Epoch 6/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7359 - loss: 0.7945 - val_accuracy: 0.7322 - val_loss: 0.7961
# Epoch 7/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7641 - loss: 0.7236 - val_accuracy: 0.7143 - val_loss: 0.8372
# Epoch 8/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.7862 - loss: 0.6441 - val_accuracy: 0.7057 - val_loss: 0.8925
# Epoch 9/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8068 - loss: 0.5788 - val_accuracy: 0.7159 - val_loss: 0.8757
# Epoch 10/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8281 - loss: 0.5206 - val_accuracy: 0.6665 - val_loss: 1.1570
# Epoch 11/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8405 - loss: 0.4815 - val_accuracy: 0.6793 - val_loss: 1.1196
# Epoch 12/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8585 - loss: 0.4307 - val_accuracy: 0.7220 - val_loss: 0.8926
# Epoch 13/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8712 - loss: 0.3906 - val_accuracy: 0.7331 - val_loss: 0.9063
# Epoch 14/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8845 - loss: 0.3532 - val_accuracy: 0.7364 - val_loss: 0.8548
# Epoch 15/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8936 - loss: 0.3210 - val_accuracy: 0.6948 - val_loss: 1.1464
# Epoch 16/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9045 - loss: 0.2923 - val_accuracy: 0.7663 - val_loss: 0.8206
# Epoch 17/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9129 - loss: 0.2662 - val_accuracy: 0.7762 - val_loss: 0.7839
# Epoch 18/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9205 - loss: 0.2426 - val_accuracy: 0.7663 - val_loss: 0.8794
# Epoch 19/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9278 - loss: 0.2199 - val_accuracy: 0.7279 - val_loss: 1.0698
# Epoch 20/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9318 - loss: 0.2084 - val_accuracy: 0.7414 - val_loss: 1.0801
# Epoch 21/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9380 - loss: 0.1907 - val_accuracy: 0.7196 - val_loss: 1.2522
# Epoch 22/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9407 - loss: 0.1851 - val_accuracy: 0.7442 - val_loss: 0.9891
# Epoch 23/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9419 - loss: 0.1819 - val_accuracy: 0.7616 - val_loss: 0.9014
# Epoch 24/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9512 - loss: 0.1581 - val_accuracy: 0.7703 - val_loss: 0.9332
# Epoch 25/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9485 - loss: 0.1573 - val_accuracy: 0.7353 - val_loss: 1.1670
# Epoch 26/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9511 - loss: 0.1537 - val_accuracy: 0.7718 - val_loss: 1.0289
# Epoch 27/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9553 - loss: 0.1476 - val_accuracy: 0.7702 - val_loss: 1.0588
# Epoch 28/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9581 - loss: 0.1319 - val_accuracy: 0.7507 - val_loss: 1.1061
# Epoch 29/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9554 - loss: 0.1442 - val_accuracy: 0.7524 - val_loss: 1.1691
# Epoch 30/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9598 - loss: 0.1276 - val_accuracy: 0.7309 - val_loss: 1.2950

# %%
plt.plot(history.history['accuracy'], label = 'accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.legend()

# %%
import cv2
img = cv2.imread('horse.webp')
plt.imshow(img)
img = cv2.resize(img, (32,32))
img = np.expand_dims(img, axis=0)
result = model.predict(img, verbose = False)
plt.title(labels[result[0].argmax()])
# Out:
# Text(0.5, 1.0, 'horse')

# %%
img.shape
# Out:
# (1, 32, 32, 3)

# %%
import urllib
import PIL

# %%
url = 'https://cdn.britannica.com/17/126517-050-9CDCBDDF/semi-semitrailer-truck-tractor-highway.jpg'
img = np.array(PIL.Image.open(urllib.request.urlopen(url)))
plt.imshow(img)
img = cv2.resize(img, (32,32))
img = np.expand_dims(img, axis=0)
result = model.predict(img, verbose = False)
plt.title(labels[result[0].argmax()])
# Out:
# Text(0.5, 1.0, 'truck')
