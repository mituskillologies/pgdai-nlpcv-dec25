# %%
pip install indic_transliteration
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

# %%
text = 'tushar kute'

# %%
ttext = transliterate(text, sanscript.ITRANS, sanscript.DEVANAGARI)

# %%
ttext
# Out:
# 'तुशर् कुते'

# %%
text = 'tuShaara kuTe'

# %%
transliterate(text, sanscript.ITRANS, sanscript.DEVANAGARI)
# Out:
# 'तुषार कुटे'

# %%
transliterate(text, sanscript.ITRANS, sanscript.BENGALI)
# Out:
# 'তুষার কুটে'

# %%
transliterate(text, sanscript.ITRANS, sanscript.TAMIL)
# Out:
# 'துஷார குடே'

# %%
text = input("Enter your name:")
text = transliterate(text, sanscript.ITRANS, sanscript.DEVANAGARI)
print("Your name:", text)
# Out:
# Enter your name: yash
# Your name: यश्
